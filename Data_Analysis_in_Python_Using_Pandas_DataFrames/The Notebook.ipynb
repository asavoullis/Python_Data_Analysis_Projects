# %% [markdown]
# # WELCOME TO THE NOTEBOOK
# ---

# %% [markdown]
# Importing Modules

# %%
import pandas as pd

# %% [markdown]
# Loading the data

# %%
data = pd.read_json("movies_dataset.json")
data
# Out:
#       color      director_name  num_critic_for_reviews  duration        gross  \
# 0     Color      James Cameron                   723.0     178.0  760505847.0
# 1     Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2     Color         Sam Mendes                   602.0     148.0  200074175.0
# 3     Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4       NaN        Doug Walker                     NaN       NaN          NaN
# ...     ...                ...                     ...       ...          ...
# 5038  Color        Scott Smith                     1.0      87.0          NaN
# 5039  Color                NaN                    43.0      43.0          NaN
# 5040  Color   Benjamin Roberds                    13.0      76.0          NaN
# 5041  Color        Daniel Hsia                    14.0     100.0      10443.0
# 5042  Color           Jon Gunn                    43.0      90.0      85222.0
#
#                                genres        star_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# 3                     Action|Thriller        Tom Hardy
# 4                         Documentary      Doug Walker
# ...                               ...              ...
# 5038                     Comedy|Drama      Eric Mabius
# 5039     Crime|Drama|Mystery|Thriller      Natalie Zea
# 5040            Drama|Horror|Thriller      Eva Boehnke
# 5041             Comedy|Drama|Romance        Alan Ruck
# 5042                      Documentary      John August
#
#                                      movie_title  \
# 0                                         Avatar
# 1       Pirates of the Caribbean: At World's End
# 2                                        Spectre
# 3                          The Dark Knight Rises
# 4     Star Wars: Episode VII - The Force Awakens
# ...                                          ...
# 5038                     Signed Sealed Delivered
# 5039                               The Following
# 5040                        A Plague So Pleasant
# 5041                            Shanghai Calling
# 5042                           My Date with Drew
#
#                                         movie_imdb_link language country  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...  English     USA
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...  English     USA
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...  English      UK
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...  English     USA
# 4     http://www.imdb.com/title/tt5289954/?ref_=fn_t...      NaN     NaN
# ...                                                 ...      ...     ...
# 5038  http://www.imdb.com/title/tt3000844/?ref_=fn_t...  English  Canada
# 5039  http://www.imdb.com/title/tt2071645/?ref_=fn_t...  English     USA
# 5040  http://www.imdb.com/title/tt2107644/?ref_=fn_t...  English     USA
# 5041  http://www.imdb.com/title/tt2070597/?ref_=fn_t...  English     USA
# 5042  http://www.imdb.com/title/tt0378407/?ref_=fn_t...  English     USA
#
#            budget  title_year  imdb_score
# 0     237000000.0      2009.0         7.9
# 1     300000000.0      2007.0         7.1
# 2     245000000.0      2015.0         6.8
# 3     250000000.0      2012.0         8.5
# 4             NaN         NaN         7.1
# ...           ...         ...         ...
# 5038          NaN      2013.0         7.7
# 5039          NaN         NaN         7.5
# 5040       1400.0      2013.0         6.3
# 5041          NaN      2012.0         6.3
# 5042       1100.0      2004.0         6.6
#
# [5043 rows x 14 columns]

# %%
data.head(2)
# data.tail(3)
# Out:
#    color   director_name  num_critic_for_reviews  duration        gross  \
# 0  Color   James Cameron                   723.0     178.0  760505847.0
# 1  Color  Gore Verbinski                   302.0     169.0  309404152.0
#
#                             genres    star_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi  CCH Pounder
# 1         Action|Adventure|Fantasy  Johnny Depp
#
#                                 movie_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                      movie_imdb_link language country  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...  English     USA
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...  English     USA
#
#         budget  title_year  imdb_score
# 0  237000000.0      2009.0         7.9
# 1  300000000.0      2007.0         7.1

# %% [markdown]
# Check the dataframe shape (#rows and #columns)

# %%
data.shape
# returns a tuple with numbers of rows and numbers of columns
# Out:
# (5043, 14)

# %% [markdown]
# Let's check the data types of the columns

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.dtypes
# column types
# Out:
# color                      object
# director_name              object
# num_critic_for_reviews    float64
# duration                  float64
# gross                     float64
# genres                     object
# star_name                  object
# movie_title                object
# movie_imdb_link            object
# language                   object
# country                    object
# budget                    float64
# title_year                float64
# imdb_score                float64
# dtype: object

# %% [markdown]
# Column Selection

# %%
data.color
# Out:
# 0       Color
# 1       Color
# 2       Color
# 3       Color
# 4         NaN
#         ...
# 5038    Color
# 5039    Color
# 5040    Color
# 5041    Color
# 5042    Color
# Name: color, Length: 5043, dtype: object

# %% [markdown]
# ---

# %%
data['budget']
# alternative way
# Out:
# 0       237000000.0
# 1       300000000.0
# 2       245000000.0
# 3       250000000.0
# 4               NaN
#            ...
# 5038            NaN
# 5039            NaN
# 5040         1400.0
# 5041            NaN
# 5042         1100.0
# Name: budget, Length: 5043, dtype: float64

# %% [markdown]
# ## Data Preparation
# Remove some columns:
#
#    - `movie_imdb_link`
#    - `num_critic_for_reviews`
#    - `genre`

# %%
data.head(3)
# Out:
#    color   director_name  num_critic_for_reviews  duration        gross  \
# 0  Color   James Cameron                   723.0     178.0  760505847.0
# 1  Color  Gore Verbinski                   302.0     169.0  309404152.0
# 2  Color      Sam Mendes                   602.0     148.0  200074175.0
#
#                             genres        star_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
#
#                                 movie_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
# 2                                   Spectre
#
#                                      movie_imdb_link language country  \
# 0  http://www.imdb.com/title/tt0499549/?ref_=fn_t...  English     USA
# 1  http://www.imdb.com/title/tt0449088/?ref_=fn_t...  English     USA
# 2  http://www.imdb.com/title/tt2379713/?ref_=fn_t...  English      UK
#
#         budget  title_year  imdb_score
# 0  237000000.0      2009.0         7.9
# 1  300000000.0      2007.0         7.1
# 2  245000000.0      2015.0         6.8

# %%
data.drop(axis=1, columns=['movie_imdb_link'])
# returns a new dataframe
# Out:
#       color      director_name  num_critic_for_reviews  duration        gross  \
# 0     Color      James Cameron                   723.0     178.0  760505847.0
# 1     Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2     Color         Sam Mendes                   602.0     148.0  200074175.0
# 3     Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4       NaN        Doug Walker                     NaN       NaN          NaN
# ...     ...                ...                     ...       ...          ...
# 5038  Color        Scott Smith                     1.0      87.0          NaN
# 5039  Color                NaN                    43.0      43.0          NaN
# 5040  Color   Benjamin Roberds                    13.0      76.0          NaN
# 5041  Color        Daniel Hsia                    14.0     100.0      10443.0
# 5042  Color           Jon Gunn                    43.0      90.0      85222.0
#
#                                genres        star_name  \
# 0     Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1            Action|Adventure|Fantasy      Johnny Depp
# 2           Action|Adventure|Thriller  Christoph Waltz
# 3                     Action|Thriller        Tom Hardy
# 4                         Documentary      Doug Walker
# ...                               ...              ...
# 5038                     Comedy|Drama      Eric Mabius
# 5039     Crime|Drama|Mystery|Thriller      Natalie Zea
# 5040            Drama|Horror|Thriller      Eva Boehnke
# 5041             Comedy|Drama|Romance        Alan Ruck
# 5042                      Documentary      John August
#
#                                      movie_title language country  \
# 0                                         Avatar  English     USA
# 1       Pirates of the Caribbean: At World's End  English     USA
# 2                                        Spectre  English      UK
# 3                          The Dark Knight Rises  English     USA
# 4     Star Wars: Episode VII - The Force Awakens      NaN     NaN
# ...                                          ...      ...     ...
# 5038                     Signed Sealed Delivered  English  Canada
# 5039                               The Following  English     USA
# 5040                        A Plague So Pleasant  English     USA
# 5041                            Shanghai Calling  English     USA
# 5042                           My Date with Drew  English     USA
#
#            budget  title_year  imdb_score
# 0     237000000.0      2009.0         7.9
# 1     300000000.0      2007.0         7.1
# 2     245000000.0      2015.0         6.8
# 3     250000000.0      2012.0         8.5
# 4             NaN         NaN         7.1
# ...           ...         ...         ...
# 5038          NaN      2013.0         7.7
# 5039          NaN         NaN         7.5
# 5040       1400.0      2013.0         6.3
# 5041          NaN      2012.0         6.3
# 5042       1100.0      2004.0         6.6
#
# [5043 rows x 13 columns]

# %%
data.drop(axis=1, columns=['movie_imdb_link'], inplace=True)
data.head()
# Out:
#    color      director_name  num_critic_for_reviews  duration        gross  \
# 0  Color      James Cameron                   723.0     178.0  760505847.0
# 1  Color     Gore Verbinski                   302.0     169.0  309404152.0
# 2  Color         Sam Mendes                   602.0     148.0  200074175.0
# 3  Color  Christopher Nolan                   813.0     164.0  448130642.0
# 4    NaN        Doug Walker                     NaN       NaN          NaN
#
#                             genres        star_name  \
# 0  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder
# 1         Action|Adventure|Fantasy      Johnny Depp
# 2        Action|Adventure|Thriller  Christoph Waltz
# 3                  Action|Thriller        Tom Hardy
# 4                      Documentary      Doug Walker
#
#                                   movie_title language country       budget  \
# 0                                      Avatar  English     USA  237000000.0
# 1    Pirates of the Caribbean: At World's End  English     USA  300000000.0
# 2                                     Spectre  English      UK  245000000.0
# 3                       The Dark Knight Rises  English     USA  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
#
#    title_year  imdb_score
# 0      2009.0         7.9
# 1      2007.0         7.1
# 2      2015.0         6.8
# 3      2012.0         8.5
# 4         NaN         7.1

# %% [markdown]
# Exercise: Remove the rest of the columns

# %%
data.drop(axis=1, columns=['num_critic_for_reviews', 'genres'], inplace=True)
data
# Out:
#       color      director_name  duration        gross        star_name  \
# 0     Color      James Cameron     178.0  760505847.0      CCH Pounder
# 1     Color     Gore Verbinski     169.0  309404152.0      Johnny Depp
# 2     Color         Sam Mendes     148.0  200074175.0  Christoph Waltz
# 3     Color  Christopher Nolan     164.0  448130642.0        Tom Hardy
# 4       NaN        Doug Walker       NaN          NaN      Doug Walker
# ...     ...                ...       ...          ...              ...
# 5038  Color        Scott Smith      87.0          NaN      Eric Mabius
# 5039  Color                NaN      43.0          NaN      Natalie Zea
# 5040  Color   Benjamin Roberds      76.0          NaN      Eva Boehnke
# 5041  Color        Daniel Hsia     100.0      10443.0        Alan Ruck
# 5042  Color           Jon Gunn      90.0      85222.0      John August
#
#                                      movie_title language country  \
# 0                                         Avatar  English     USA
# 1       Pirates of the Caribbean: At World's End  English     USA
# 2                                        Spectre  English      UK
# 3                          The Dark Knight Rises  English     USA
# 4     Star Wars: Episode VII - The Force Awakens      NaN     NaN
# ...                                          ...      ...     ...
# 5038                     Signed Sealed Delivered  English  Canada
# 5039                               The Following  English     USA
# 5040                        A Plague So Pleasant  English     USA
# 5041                            Shanghai Calling  English     USA
# 5042                           My Date with Drew  English     USA
#
#            budget  title_year  imdb_score
# 0     237000000.0      2009.0         7.9
# 1     300000000.0      2007.0         7.1
# 2     245000000.0      2015.0         6.8
# 3     250000000.0      2012.0         8.5
# 4             NaN         NaN         7.1
# ...           ...         ...         ...
# 5038          NaN      2013.0         7.7
# 5039          NaN         NaN         7.5
# 5040       1400.0      2013.0         6.3
# 5041          NaN      2012.0         6.3
# 5042       1100.0      2004.0         6.6
#
# [5043 rows x 11 columns]

# %% [markdown]
# Let's check the shape again

# %%
data.head()
# Out:
#    color      director_name  duration        gross        star_name  \
# 0  Color      James Cameron     178.0  760505847.0      CCH Pounder
# 1  Color     Gore Verbinski     169.0  309404152.0      Johnny Depp
# 2  Color         Sam Mendes     148.0  200074175.0  Christoph Waltz
# 3  Color  Christopher Nolan     164.0  448130642.0        Tom Hardy
# 4    NaN        Doug Walker       NaN          NaN      Doug Walker
#
#                                   movie_title language country       budget  \
# 0                                      Avatar  English     USA  237000000.0
# 1    Pirates of the Caribbean: At World's End  English     USA  300000000.0
# 2                                     Spectre  English      UK  245000000.0
# 3                       The Dark Knight Rises  English     USA  250000000.0
# 4  Star Wars: Episode VII - The Force Awakens      NaN     NaN          NaN
#
#    title_year  imdb_score
# 0      2009.0         7.9
# 1      2007.0         7.1
# 2      2015.0         6.8
# 3      2012.0         8.5
# 4         NaN         7.1

# %%
data.shape
# Out:
# (5043, 11)

# %% [markdown]
# Let's convert the dtype of `title_year` column to integer

# %%
data.title_year
# Out:
# 0       2009.0
# 1       2007.0
# 2       2015.0
# 3       2012.0
# 4          NaN
#          ...
# 5038    2013.0
# 5039       NaN
# 5040    2013.0
# 5041    2012.0
# 5042    2004.0
# Name: title_year, Length: 5043, dtype: float64

# %%
# lets convert it from float to int
data.title_year = data.title_year.astype("Int64")
data.head(3)
# Out:
#    color   director_name  duration        gross        star_name  \
# 0  Color   James Cameron     178.0  760505847.0      CCH Pounder
# 1  Color  Gore Verbinski     169.0  309404152.0      Johnny Depp
# 2  Color      Sam Mendes     148.0  200074175.0  Christoph Waltz
#
#                                 movie_title language country       budget  \
# 0                                    Avatar  English     USA  237000000.0
# 1  Pirates of the Caribbean: At World's End  English     USA  300000000.0
# 2                                   Spectre  English      UK  245000000.0
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1
# 2        2015         6.8

# %% [markdown]
# Let's check the dataframe again

# %%
data.tail(2)
# Out:
#       color director_name  duration    gross    star_name        movie_title  \
# 5041  Color   Daniel Hsia     100.0  10443.0    Alan Ruck   Shanghai Calling
# 5042  Color      Jon Gunn      90.0  85222.0  John August  My Date with Drew
#
#      language country  budget  title_year  imdb_score
# 5041  English     USA     NaN        2012         6.3
# 5042  English     USA  1100.0        2004         6.6

# %% [markdown]
# Renaming some columns:
# - changing `gross` to `movie_income`

# %%
rename_dict = {"gross": "movie_income", "language" : "Language"}
data.rename(columns= rename_dict, inplace=True)
data.head(2)
# Out:
#    color   director_name  duration  movie_income    star_name  \
# 0  Color   James Cameron     178.0   760505847.0  CCH Pounder
# 1  Color  Gore Verbinski     169.0   309404152.0  Johnny Depp
#
#                                 movie_title Language country       budget  \
# 0                                    Avatar  English     USA  237000000.0
# 1  Pirates of the Caribbean: At World's End  English     USA  300000000.0
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1

# %% [markdown]
# Exercise: Rename the `budget` column to `movie_budget`

# %%
rename_dict = {"budget": "movie_budget"}
data.rename(columns= rename_dict, inplace=True)
data.head(2)
# Out:
#    color   director_name  duration  movie_income    star_name  \
# 0  Color   James Cameron     178.0   760505847.0  CCH Pounder
# 1  Color  Gore Verbinski     169.0   309404152.0  Johnny Depp
#
#                                 movie_title Language country  movie_budget  \
# 0                                    Avatar  English     USA   237000000.0
# 1  Pirates of the Caribbean: At World's End  English     USA   300000000.0
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1

# %% [markdown]
# ---
# ### Data Analysis
#
#
# Let's checkout the distribution of `duration` column using a histogram.

# %%
data.head(5)
# Out:
#    color      director_name  duration  movie_income        star_name  \
# 0  Color      James Cameron     178.0   760505847.0      CCH Pounder
# 1  Color     Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2  Color         Sam Mendes     148.0   200074175.0  Christoph Waltz
# 3  Color  Christopher Nolan     164.0   448130642.0        Tom Hardy
# 4    NaN        Doug Walker       NaN           NaN      Doug Walker
#
#                                   movie_title Language country  movie_budget  \
# 0                                      Avatar  English     USA   237000000.0
# 1    Pirates of the Caribbean: At World's End  English     USA   300000000.0
# 2                                     Spectre  English      UK   245000000.0
# 3                       The Dark Knight Rises  English     USA   250000000.0
# 4  Star Wars: Episode VII - The Force Awakens      NaN     NaN           NaN
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1
# 2        2015         6.8
# 3        2012         8.5
# 4        <NA>         7.1

# %%
data.duration
# Out:
# 0       178.0
# 1       169.0
# 2       148.0
# 3       164.0
# 4         NaN
#         ...
# 5038     87.0
# 5039     43.0
# 5040     76.0
# 5041    100.0
# 5042     90.0
# Name: duration, Length: 5043, dtype: float64

# %%
data.duration.hist()
# over 2500 movies have duration between 90 and 105 minutes approximately
# Out:
# <AxesSubplot:>

# %%
ax = data.duration.hist(bins=20, figsize=(8,6), grid= False)
ax.set_xlabel("Movie Durations")
ax.set_ylabel("Count")
ax.set_title("Movie Durations Historgram")
# Out:
# Text(0.5, 1.0, 'Movie Durations Historgram')

# %% [markdown]
# Exercise: Create a hitogram to see the distribution of `imdb_score` column

# %%
ax =data.imdb_score.hist(grid=False, figsize=(10,8), bins=25 )
ax.set_title("Movie IMDB score histogram")
ax.set_xlabel("Scores")
ax.set_ylabel("Count")

# over 500 movies have scores between 6 and 7.5
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# Let's check how many movies have the `imdb_score` less than `4`.

# %%
data.imdb_score
# Out:
# 0       7.9
# 1       7.1
# 2       6.8
# 3       8.5
# 4       7.1
#        ...
# 5038    7.7
# 5039    7.5
# 5040    6.3
# 5041    6.3
# 5042    6.6
# Name: imdb_score, Length: 5043, dtype: float64

# %%
data.imdb_score < 4
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5038    False
# 5039    False
# 5040    False
# 5041    False
# 5042    False
# Name: imdb_score, Length: 5043, dtype: bool

# %%
low_score_movies = data[data["imdb_score"] < 4]
low_score_movies
# Out:
#       color       director_name  duration  movie_income        star_name  \
# 217   Color     Joel Schumacher     125.0   107285004.0    Michael Gough
# 267   Color         Jan de Bont     121.0    48068396.0     Jason Patric
# 273   Color            Bo Welch      82.0   100446895.0       Sean Hayes
# 313   Color               Pitof      87.0    40198710.0   Frances Conroy
# 319   Color   Lawrence Guterman      94.0    17010646.0    Jamie Kennedy
# ...     ...                 ...       ...           ...              ...
# 4988  Color   Terron R. Parsons      93.0           NaN    Richard Tyson
# 5000  Color        Travis Legge      83.0           NaN   Elissa Dowling
# 5002  Color  Collin Joseph Neal      75.0           NaN  Julianne Gabert
# 5017  Color        Travis Legge      90.0           NaN   Kristen Seavey
# 5020    NaN     Brandon Landers     143.0           NaN    Robbie Barnes
#
#                   movie_title Language country  movie_budget  title_year  \
# 217            Batman & Robin  English     USA   125000000.0        1997
# 267   Speed 2: Cruise Control  English     USA   160000000.0        1997
# 273        The Cat in the Hat  English     USA   109000000.0        2003
# 313                  Catwoman  English     USA   100000000.0        2004
# 319           Son of the Mask  English     USA    84000000.0        2005
# ...                       ...      ...     ...           ...         ...
# 4988                  Hayride  English     USA       60000.0        2012
# 5000           Raymond Did It  English     USA       40000.0        2011
# 5002           Run, Hide, Die  English     USA       50000.0        2012
# 5017                Dry Spell  English     USA       22000.0        2013
# 5020               The Ridges  English     USA       17350.0        2011
#
#       imdb_score
# 217          3.7
# 267          3.7
# 273          3.8
# 313          3.3
# 319          2.2
# ...          ...
# 4988         3.4
# 5000         3.2
# 5002         3.7
# 5017         3.3
# 5020         3.0
#
# [156 rows x 11 columns]

# %%
low_score_movies.shape
# Out:
# (156, 11)

# %% [markdown]
# Exercise: Use a histogram to visualize the distribution of movie IMdb score in that are produced in `USA`.

# %%
usa_movies = data[data.country == "USA"]
usa_movies
# Out:
#       color      director_name  duration  movie_income     star_name  \
# 0     Color      James Cameron     178.0   760505847.0   CCH Pounder
# 1     Color     Gore Verbinski     169.0   309404152.0   Johnny Depp
# 3     Color  Christopher Nolan     164.0   448130642.0     Tom Hardy
# 5     Color     Andrew Stanton     132.0    73058679.0  Daryl Sabara
# 6     Color          Sam Raimi     156.0   336530303.0  J.K. Simmons
# ...     ...                ...       ...           ...           ...
# 5037  Color       Edward Burns      95.0        4584.0  Kerry Bish̩
# 5039  Color                NaN      43.0           NaN   Natalie Zea
# 5040  Color   Benjamin Roberds      76.0           NaN   Eva Boehnke
# 5041  Color        Daniel Hsia     100.0       10443.0     Alan Ruck
# 5042  Color           Jon Gunn      90.0       85222.0   John August
#
#                                    movie_title Language country  movie_budget  \
# 0                                       Avatar  English     USA   237000000.0
# 1     Pirates of the Caribbean: At World's End  English     USA   300000000.0
# 3                        The Dark Knight Rises  English     USA   250000000.0
# 5                                  John Carter  English     USA   263700000.0
# 6                                 Spider-Man 3  English     USA   258000000.0
# ...                                        ...      ...     ...           ...
# 5037                                 Newlyweds  English     USA        9000.0
# 5039                             The Following  English     USA           NaN
# 5040                      A Plague So Pleasant  English     USA        1400.0
# 5041                          Shanghai Calling  English     USA           NaN
# 5042                         My Date with Drew  English     USA        1100.0
#
#       title_year  imdb_score
# 0           2009         7.9
# 1           2007         7.1
# 3           2012         8.5
# 5           2012         6.6
# 6           2007         6.2
# ...          ...         ...
# 5037        2011         6.4
# 5039        <NA>         7.5
# 5040        2013         6.3
# 5041        2012         6.3
# 5042        2004         6.6
#
# [3807 rows x 11 columns]

# %%
data[data.country == "USA"].imdb_score.hist(grid = False, bins = 25)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ---
# ### Let's answer to some analytical questions
#
# Question 1 - In which year we have the `highest` and `lowest` number of movies?

# %% [markdown]
# Now finding out number of movies per year

# %%
data.head()
# Out:
#    color      director_name  duration  movie_income        star_name  \
# 0  Color      James Cameron     178.0   760505847.0      CCH Pounder
# 1  Color     Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2  Color         Sam Mendes     148.0   200074175.0  Christoph Waltz
# 3  Color  Christopher Nolan     164.0   448130642.0        Tom Hardy
# 4    NaN        Doug Walker       NaN           NaN      Doug Walker
#
#                                   movie_title Language country  movie_budget  \
# 0                                      Avatar  English     USA   237000000.0
# 1    Pirates of the Caribbean: At World's End  English     USA   300000000.0
# 2                                     Spectre  English      UK   245000000.0
# 3                       The Dark Knight Rises  English     USA   250000000.0
# 4  Star Wars: Episode VII - The Force Awakens      NaN     NaN           NaN
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1
# 2        2015         6.8
# 3        2012         8.5
# 4        <NA>         7.1

# %%
movie_count_per_year = data.groupby("title_year").size()
movie_count_per_year
# Out:
# title_year
# 1916      1
# 1920      1
# 1925      1
# 1927      1
# 1929      2
#        ...
# 2012    221
# 2013    237
# 2014    252
# 2015    226
# 2016    106
# Length: 91, dtype: int64

# %%
movie_count_per_year[2010]
# Out:
# 230

# %%
movie_count_per_year.max()
# Out:
# 260

# %%
movie_count_per_year.idxmax()
# Out:
# 2009

# %%
movie_count_per_year.idxmin()
# Out:
# 1916

# %%
movie_count_per_year.min()
# Out:
# 1

# %% [markdown]
# Let's create a line chart to show the result

# %%
ax = movie_count_per_year.plot(figsize = (8,6))
ax.set_xlabel("Years")
ax.set_ylabel("# of Movies")
# Out:
# Text(0, 0.5, '# of Movies')

# %% [markdown]
# Question 2 - In which year we have `minimum` and `maximum` average `imdb_score` ?

# %% [markdown]
# Finding average imdb score per year

# %%
average_imdb_score_per_year = data.groupby("title_year")['imdb_score'].mean()
average_imdb_score_per_year
# Out:
# title_year
# 1916    8.000000
# 1920    4.800000
# 1925    8.300000
# 1927    8.300000
# 1929    7.150000
#           ...
# 2012    6.266516
# 2013    6.369620
# 2014    6.228175
# 2015    6.033628
# 2016    6.399057
# Name: imdb_score, Length: 91, dtype: float64

# %% [markdown]
# Let's Use a barchart to visualize the result

# %%
ax = average_imdb_score_per_year.plot.bar(figsize = (18,8), title = "Average Imdb Score per Year")
ax.set_xlabel = "Year"
ax.set_ylabel = "Average Score per Year"

# %% [markdown]
# Exercise:
# Question 3 - In which year we have the `minimum` and `maximum` spent movie budget?
#
# `hint: use a line chart to visualize your results.`

# %%
data.groupby("title_year")['movie_budget'].sum().plot()
# Out:
# <AxesSubplot:xlabel='title_year'>

# %%
data.groupby("title_year")['movie_budget'].sum().idxmax()
# Out:
# 2006

# %%
data.groupby("title_year")['movie_budget'].sum().max()
# Out:
# 20019582000.0

# %%
data.groupby("title_year")['movie_budget'].sum().min()
# Out:
# 100000.0

# %%
data.groupby("title_year")['movie_budget'].sum().idxmin()
# Out:
# 1920

# %% [markdown]
# Question 4 - Is there any relationship between IMdb score of a movie and the movie income?
#
# To approaches to solve this question:
# - Visual Correlation Analysis
# - Generating the Correlation Matirx

# %%
data.head()
# Out:
#    color      director_name  duration  movie_income        star_name  \
# 0  Color      James Cameron     178.0   760505847.0      CCH Pounder
# 1  Color     Gore Verbinski     169.0   309404152.0      Johnny Depp
# 2  Color         Sam Mendes     148.0   200074175.0  Christoph Waltz
# 3  Color  Christopher Nolan     164.0   448130642.0        Tom Hardy
# 4    NaN        Doug Walker       NaN           NaN      Doug Walker
#
#                                   movie_title Language country  movie_budget  \
# 0                                      Avatar  English     USA   237000000.0
# 1    Pirates of the Caribbean: At World's End  English     USA   300000000.0
# 2                                     Spectre  English      UK   245000000.0
# 3                       The Dark Knight Rises  English     USA   250000000.0
# 4  Star Wars: Episode VII - The Force Awakens      NaN     NaN           NaN
#
#    title_year  imdb_score
# 0        2009         7.9
# 1        2007         7.1
# 2        2015         6.8
# 3        2012         8.5
# 4        <NA>         7.1

# %%
data_q4 = data[['imdb_score',"movie_income"]]
data_q4
# Out:
#       imdb_score  movie_income
# 0            7.9   760505847.0
# 1            7.1   309404152.0
# 2            6.8   200074175.0
# 3            8.5   448130642.0
# 4            7.1           NaN
# ...          ...           ...
# 5038         7.7           NaN
# 5039         7.5           NaN
# 5040         6.3           NaN
# 5041         6.3       10443.0
# 5042         6.6       85222.0
#
# [5043 rows x 2 columns]

# %% [markdown]
# Let's drop the rows with `non` values

# %%
data_q4.dropna(inplace=True)
data_q4
# Out:
# C:\Users\Bluthund\AppData\Local\Temp\ipykernel_4972\3112502584.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_q4.dropna(inplace=True)
#       imdb_score  movie_income
# 0            7.9   760505847.0
# 1            7.1   309404152.0
# 2            6.8   200074175.0
# 3            8.5   448130642.0
# 5            6.6    73058679.0
# ...          ...           ...
# 5034         6.3       70071.0
# 5035         6.9     2040920.0
# 5037         6.4        4584.0
# 5041         6.3       10443.0
# 5042         6.6       85222.0
#
# [4159 rows x 2 columns]

# %% [markdown]
# Let's create a scatter plot to see the data

# %%
data_q4.plot.scatter(x= "movie_income", y = "imdb_score", figsize =(10,10))
# non linear relationship between movie income and imdb_score
# Out:
# <AxesSubplot:xlabel='movie_income', ylabel='imdb_score'>

# %% [markdown]
# Let's generate the correlation matrix

# %%
data_q4.corr()
# Out:
#               imdb_score  movie_income
# imdb_score      1.000000      0.198021
# movie_income    0.198021      1.000000
